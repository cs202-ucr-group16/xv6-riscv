# %%
# 8 4 2 1 CASE
stride_100 = [52, 27, 14, 7]
stride_80 = [42, 21, 11, 6]
stride_60 = [32, 16, 8, 4]
stride_40 = [20, 11, 6, 3]
stride_20 = [10, 5, 3, 2]



proc_a_stride = [10, 20, 32, 42, 52]
proc_b_stride = [5, 11, 16, 21, 27]
proc_c_stride = [3, 6, 8, 11, 14]
proc_d_stride = [2, 3, 4, 6, 7]


proc_a_lottery = [10.8, 21, 30.8, 40.8, 45.8]
proc_b_lottery = [5, 10, 15.8, 21.6, 30.6]
proc_c_lottery = [3, 5.8, 8.8, 11, 12.6]
proc_d_lottery = [1.2, 3.2, 4.8, 6.6, 11]


proc_a_ideal = [10.66, 21.32, 31.95, 42.66, 53.3]
proc_b_ideal = [5.33, 10.66, 15.97, 21.33, 26.65]
proc_c_ideal = [2.66, 5.33, 7.98, 10.66, 13.32]
proc_d_ideal = [1.33, 2.66, 3.99, 5.33, 6.66]

lottery_100 = [45.8, 30.6, 12.6, 11].reverse()
lottery_80 = [40.8, 21.6, 11,  6.6].reverse()
lottery_60 = [30.8, 15.8, 8.8,  4.8].reverse()
lottery_40 = [21, 10, 5.8, 3.2].reverse()
lottery_20 = [10.8, 5, 3, 1.2].reverse()

x = [100, 80, 60, 40, 20]
x.reverse()

# %%
# stride scheduling

import matplotlib.pyplot as plt
fig, ax = plt.subplots()

ax.plot(x, proc_a_stride, label='8 tickets')
ax.plot(x, proc_b_stride, label='4 tickets')
ax.plot(x, proc_c_stride, label='2 tickets')
ax.plot(x, proc_d_stride, label='1 ticket')

plt.plot(x, proc_a_ideal, linestyle='dashed', label='ideal', color='gray')
plt.plot(x, proc_b_ideal, linestyle='dashed', color='gray')
plt.plot(x, proc_c_ideal, linestyle='dashed', color='gray')
plt.plot(x, proc_d_ideal, linestyle='dashed', color='gray')

plt.xlabel("Time (quanta)")
plt.ylabel("Cumulative quanta")
plt.title("Stride Scheduling (8 4 2 1)")

ax.legend()

plt.show()

# %%
# lottery scheduling

import matplotlib.pyplot as plt
fig, ax = plt.subplots()

ax.plot(x, proc_a_lottery, label='8 tickets')
ax.plot(x, proc_b_lottery, label='4 tickets')
ax.plot(x, proc_c_lottery, label='2 tickets')
ax.plot(x, proc_d_lottery, label='1 ticket')

plt.plot(x, proc_a_ideal, linestyle='dashed', label='ideal', color='gray')
plt.plot(x, proc_b_ideal, linestyle='dashed', color='gray')
plt.plot(x, proc_c_ideal, linestyle='dashed', color='gray')
plt.plot(x, proc_d_ideal, linestyle='dashed', color='gray')

plt.xlabel("Time (quanta)")
plt.ylabel("Cumulative quanta")
plt.title("Lottery Scheduling (8 4 2 1)")

ax.legend()

plt.show()

# %%
# 1 1 1 1 CASE
stride_100 = [25, 25, 25, 25]
stride_80 = [20, 20, 20, 20]
stride_60 = [15, 15, 15, 15]
stride_40 = [10, 10, 10, 10]
stride_20 = [5, 5, 5, 5]



proc_a_stride = [5, 10, 15, 20, 25]
proc_b_stride = [5, 10, 15, 20, 25]
proc_c_stride = [5, 10, 15, 20, 25]
proc_d_stride = [5, 10, 15, 20, 25]


proc_a_lottery = [6.6, 8.6, 16, 19, 26.8]
proc_b_lottery = [5.2, 10.6, 13.8, 19.2, 23.4]
proc_c_lottery = [4.6, 12, 15, 24.6, 22.4]
proc_d_lottery = [3.6, 8.8, 15.52, 17.2, 27.4]


proc_a_ideal = [5, 10, 15, 20, 25]
proc_b_ideal = [5, 10, 15, 20, 25]
proc_c_ideal = [5, 10, 15, 20, 25]
proc_d_ideal = [5, 10, 15, 20, 25]

lottery_100 = [26.8, 23.4, 22.4, 27.4]
lottery_80 = [19, 19.2, 24.6, 17.2]
lottery_60 = [16, 13.8, 15, 15.52]
lottery_40 = [8.6, 10.6, 12, 8.8]
lottery_20 = [6.6, 5.2, 4.6, 3.6]

x = [100, 80, 60, 40, 20]
x.reverse()

# %%
# lottery scheduling

import matplotlib.pyplot as plt
fig, ax = plt.subplots()

ax.plot(x, proc_a_lottery, label='1 ticket')
ax.plot(x, proc_b_lottery, label='1 ticket')
ax.plot(x, proc_c_lottery, label='1 ticket')
ax.plot(x, proc_d_lottery, label='1 ticket')

plt.plot(x, proc_a_ideal, linestyle='dashed', label='ideal', color='gray')
plt.plot(x, proc_b_ideal, linestyle='dashed', color='gray')
plt.plot(x, proc_c_ideal, linestyle='dashed', color='gray')
plt.plot(x, proc_d_ideal, linestyle='dashed', color='gray')

plt.xlabel("Time (quanta)")
plt.xlabel("Cumulative quanta")
plt.title("Lottery Scheduling (1 1 1 1)")

ax.legend()

plt.show()

# %%
# stride scheduling

import matplotlib.pyplot as plt
fig, ax = plt.subplots()

ax.plot(x, proc_a_stride, label='1 ticket')
ax.plot(x, proc_b_stride, label='1 ticket')
ax.plot(x, proc_c_stride, label='1 ticket')
ax.plot(x, proc_d_stride, label='1 ticket')

plt.plot(x, proc_a_ideal, linestyle='dashed', label='ideal', color='gray')
plt.plot(x, proc_b_ideal, linestyle='dashed', color='gray')
plt.plot(x, proc_c_ideal, linestyle='dashed', color='gray')
plt.plot(x, proc_d_ideal, linestyle='dashed', color='gray')

plt.xlabel("Time (quanta)")
plt.ylabel("Cumulative quanta")
plt.title("Stride Scheduling (1 1 1 1)")

ax.legend()

plt.show()
